# %% [markdown]
# # Step 0 - Colab Connection

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
folder="/content/drive/MyDrive/資料科學自學聖經/Fan_AOI_Austin"

# %% [markdown]
# # Step 1 - Labeling the input dataset and run the CNN model
# ### Show the filters during the training

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.callbacks import Callback
import matplotlib.pyplot as plt
import numpy as np

# Set up paths
base_dir = "/content/drive/MyDrive/資料科學自學聖經/Fan_AOI_Austin/Photos"

# Data augmentation and normalization for training
train_datagen = ImageDataGenerator(rescale=1.0 / 255.0, validation_split=0.2)  # 20% for validation

# Load training data
train_generator = train_datagen.flow_from_directory(
    base_dir,
    target_size=(80, 80),
    batch_size=32,
    class_mode='binary',  # 'binary' because it's a 2-class problem (GO/NG)
    subset='training'
)

# Load validation data
validation_generator = train_datagen.flow_from_directory(
    base_dir,
    target_size=(80, 80),
    batch_size=32,
    class_mode='binary',
    subset='validation'
)

# Define a simple CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(80, 80, 3)),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(1, activation='sigmoid')  # Use 'sigmoid' for binary classification
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

class FilterVisualizationCallback(Callback):
    def __init__(self):
        super().__init__()
        self.prev_filters = None  # Store filters from the previous epoch
        self.layer_index = 0  # Start with the first layer

    def on_epoch_end(self, epoch, logs=None):
        # Check if the layer has weights before attempting to extract them
        if len(self.model.layers[self.layer_index].get_weights()) > 0:
            # Extract the filters of the specified layer
            filters, biases = self.model.layers[self.layer_index].get_weights()
            filters_normalized = (filters - filters.min()) / (filters.max() - filters.min())  # Normalize

            # Check if filters have changed
            if self.prev_filters is not None and np.allclose(filters_normalized, self.prev_filters):
                print(f"Filters of Layer {self.layer_index} did not change at Epoch {epoch + 1}.")
            else:
                self.prev_filters = filters_normalized
                # Plot filters
                n_filters = filters.shape[-1]
                plt.figure(figsize=(10, 10))
                for i in range(min(16, n_filters)):  # Visualize up to 16 filters
                    f = filters_normalized[:, :, :, i]
                    plt.subplot(4, 4, i + 1)
                    plt.imshow(f[:, :, 0], cmap='gray')
                    plt.axis('off')
                plt.suptitle(f"Filters of Layer {self.layer_index} at Epoch {epoch + 1}")
                plt.tight_layout()
                plt.show()

            # Increment the layer index for the next epoch, if applicable
            if self.layer_index < len(self.model.layers) - 1:
                self.layer_index += 1
        else:
            print(f" Layer {self.layer_index} has no weights to visualize.")

# Add the callback to model training
filter_viz_callback = FilterVisualizationCallback()

# Train the model with the callback
model.fit(
    train_generator,
    epochs=10,
    validation_data=validation_generator,
    callbacks=[filter_viz_callback]
)

# Save the trained model
model.save("fan_model.h5")

model.summary()
# Out:
# Found 270 images belonging to 2 classes.
# Found 66 images belonging to 2 classes.
# Epoch 1/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.5659 - loss: 1.3425
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 768ms/step - accuracy: 0.5638 - loss: 1.3182 - val_accuracy: 0.6212 - val_loss: 0.6606
# Epoch 2/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.5986 - loss: 0.7029 Layer 1 has no weights to visualize.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 407ms/step - accuracy: 0.6006 - loss: 0.7000 - val_accuracy: 0.6212 - val_loss: 0.6578
# Epoch 3/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.6189 - loss: 0.6280 Layer 1 has no weights to visualize.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 501ms/step - accuracy: 0.6274 - loss: 0.6250 - val_accuracy: 0.8030 - val_loss: 0.6540
# Epoch 4/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.7643 - loss: 0.5095 Layer 1 has no weights to visualize.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 391ms/step - accuracy: 0.7675 - loss: 0.5068 - val_accuracy: 0.7727 - val_loss: 0.6292
# Epoch 5/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.8954 - loss: 0.3585 Layer 1 has no weights to visualize.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 370ms/step - accuracy: 0.8966 - loss: 0.3554 - val_accuracy: 0.4394 - val_loss: 0.8982
# Epoch 6/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.9304 - loss: 0.2536 Layer 1 has no weights to visualize.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 420ms/step - accuracy: 0.9330 - loss: 0.2478 - val_accuracy: 0.8182 - val_loss: 0.5224
# Epoch 7/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.9588 - loss: 0.1376 Layer 1 has no weights to visualize.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 384ms/step - accuracy: 0.9592 - loss: 0.1355 - val_accuracy: 0.8485 - val_loss: 0.4742
# Epoch 8/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.9947 - loss: 0.0747 Layer 1 has no weights to visualize.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 549ms/step - accuracy: 0.9941 - loss: 0.0744 - val_accuracy: 0.8485 - val_loss: 0.3174
# Epoch 9/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.9795 - loss: 0.0570 Layer 1 has no weights to visualize.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 395ms/step - accuracy: 0.9793 - loss: 0.0584 - val_accuracy: 0.6364 - val_loss: 0.6569
# Epoch 10/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.9828 - loss: 0.0523 Layer 1 has no weights to visualize.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 546ms/step - accuracy: 0.9827 - loss: 0.0540 - val_accuracy: 0.8939 - val_loss: 0.2752
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)                    │ (None, 78, 78, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 39, 39, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 37, 37, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 18, 18, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_3 (Flatten)                  │ (None, 20736)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 128)                 │       2,654,336 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 8,021,573 (30.60 MB)
#  Trainable params: 2,673,857 (10.20 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 5,347,716 (20.40 MB)

# %% [markdown]
# ## Step 1.1 - Show the Accuracy

# %%
# Evaluate the model
score = model.evaluate(validation_generator, verbose=1)
print(f"Validation Loss: {score[0]}")
print(f"Validation Accuracy: {score[1]}")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 212ms/step - accuracy: 0.8923 - loss: 0.2936
# Validation Loss: 0.27523282170295715
# Validation Accuracy: 0.8939393758773804

# %% [markdown]
# ## Step 1.2 - Filters for 1st Convolution layer

# %%
#--------------check filters-------------------------
# Extract the weights of the first convolutional layer
filters, biases = model.layers[0].get_weights()

# Normalize filter values for visualization
filters = (filters - filters.min()) / (filters.max() - filters.min())

# Plot filters
import matplotlib.pyplot as plt
n_filters = filters.shape[-1]  # Number of filters
for i in range(n_filters):
    f = filters[:, :, :, i]  # Extract each filter
    plt.subplot(4, 8, i+1)   # Adjust rows and columns as needed
    plt.imshow(f[:, :, 0], cmap='gray')  # Visualize filter as grayscale
    plt.axis('off')
plt.show()
#-----------end of check filters-----------------

# %% [markdown]
# ## Step 1.3 - Filters for the 2nd Convolution layer

# %%
# Extract the weights of the second convolutional layer
filters, biases = model.layers[2].get_weights()

# Normalize filter values for visualization
filters = (filters - filters.min()) / (filters.max() - filters.min())

# Plot filters
import matplotlib.pyplot as plt
n_filters = filters.shape[-1]  # Number of filters
n_channels = filters.shape[-2]  # Number of channels in each filter

plt.figure(figsize=(20, 10))
for i in range(n_filters):
    # Combine all channels of a filter into a single 2D image
    f = filters[:, :, :, i].mean(axis=-1)  # Average across channels
    plt.subplot(8, 8, i+1)  # Create a grid (adjust rows/columns if needed)
    plt.imshow(f, cmap='gray')  # Visualize filter as grayscale
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Step 2 - Classify and Prediction

# %%
import cv2
import numpy as np
import tensorflow as tf
import glob
import os

# Load the pre-trained model
model = tf.keras.models.load_model("fan_model.h5")

# Recompile the model to suppress the warning
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Function to classify a single image
def classify_image(image_path):
    img = cv2.imread(image_path)
    if img is None:
        print(f"Error: Unable to read image at {image_path}")
        return None, None
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (80, 80))
    img = img.reshape(1, 80, 80, 3) / 255.0  # Normalize
    prediction = model.predict(img)

    # Handle cases where the prediction might not be well-formed-------test
    if prediction is not None and len(prediction) > 0:
        class_idx = 1 if prediction[0] >= 0.5 else 0  # Threshold for binary classification
        confidence = prediction[0][0] * 100  # Confidence score in percentage
        return class_idx, confidence
    else:
        return None, None

# Function to classify all images in given directories
def classify_images_in_directories(directories):
    for directory_path in directories:
        print(f"\nClassifying images in directory: {directory_path}")

        # Use glob to find all image files (supports .jpg, .png, .jpeg)
        image_files = glob.glob(os.path.join(directory_path, "*.jpg")) + \
                      glob.glob(os.path.join(directory_path, "*.png")) + \
                      glob.glob(os.path.join(directory_path, "*.jpeg"))

        if not image_files:
            print("No images found in the directory!")
            continue

        for image_path in image_files:
            result, confidence = classify_image(image_path)
            if result is not None:
                if result == 1:
                    print(f"NG (Defective) with {confidence:.2f}% confidence for image: {os.path.basename(image_path)}")
                    # print(f"GO (Correctly Aligned) with {confidence:.2f}% confidence for image: {os.path.basename(image_path)}")
                else:
                    print(f"GO (Correctly Aligned) with {confidence:.2f}% confidence for image: {os.path.basename(image_path)}")
                    # print(f"NG (Defective) with {confidence:.2f}% confidence for image: {os.path.basename(image_path)}")
            else:
                print(f"Unable to classify image: {os.path.basename(image_path)}")

# Example usage: Classify images from both "60" and "100" folders

directories = "/content/drive/MyDrive/資料科學自學聖經/Fan_AOI_Austin/Photos/60", "/content/drive/MyDrive/資料科學自學聖經/Fan_AOI_Austin/Photos/100"
# base_dir = "C:/OneDrive/! Juxer/TVDI/趙雲瀚老師/Workplace/Project/Fan_AOI_Austin/Photos"
classify_images_in_directories(directories)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Classifying images in directory: /content/drive/MyDrive/資料科學自學聖經/Fan_AOI_Austin/Photos/60
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# NG (Defective) with 98.54% confidence for image: image039.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# NG (Defective) with 99.92% confidence for image: image050.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NG (Defective) with 99.92% confidence for image: image062.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# NG (Defective) with 99.20% confidence for image: image043.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# NG (Defective) with 99.94% confidence for image: image057.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# NG (Defective) with 99.91% confidence for image: image058.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# NG (Defective) with 99.92% confidence for image: image055.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# NG (Defective) with 99.92% confidence for image: image046.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# NG (Defective) with 99.95% confidence for image: image063.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# NG (Defective) with 99.88% confidence for image: image038.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# NG (Defective) with 99.82% confidence for image: image-30-C29041.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# NG (Defective) with 99.19% confidence for image: image040.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# NG (Defective) with 99.92% confidence for image: image061.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# NG (Defective) with 99.94% confidence for image: image047.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# NG (Defective) with 99.92% confidence for image: image064.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# NG (Defective) with 99.94% confidence for image: image037.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# NG (Defective) with 99.94% confidence for image: image059.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# NG (Defective) with 99.94% confidence for image: image051.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# NG (Defective) with 99.91% confidence for image: image052.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# NG (Defective) with 99.92% confidence for image: image049.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# NG (Defective) with 99.95% confidence for image: image041.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# NG (Defective) with 99.92% confidence for image: image056.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# NG (Defective) with 97.65% confidence for image: image-30-C29030.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# NG (Defective) with 99.94% confidence for image: image060.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# NG (Defective) with 94.96% confidence for image: image032.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# NG (Defective) with 99.94% confidence for image: image053.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# NG (Defective) with 99.98% confidence for image: image-30-C29057.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# NG (Defective) with 99.68% confidence for image: image031.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# NG (Defective) with 99.92% confidence for image: image025.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# NG (Defective) with 99.94% confidence for image: image026.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# NG (Defective) with 99.95% confidence for image: image024.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# NG (Defective) with 99.98% confidence for image: image-30-C29063.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# NG (Defective) with 97.30% confidence for image: image029.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# NG (Defective) with 93.07% confidence for image: image-30-C29042.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# NG (Defective) with 99.98% confidence for image: image-30-C29060.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# NG (Defective) with 99.98% confidence for image: image-30-C29061.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# NG (Defective) with 99.91% confidence for image: image027.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# NG (Defective) with 99.98% confidence for image: image-30-C29056.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# NG (Defective) with 98.18% confidence for image: image042.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# NG (Defective) with 99.95% confidence for image: image054.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# NG (Defective) with 99.98% confidence for image: image-30-C29055.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# NG (Defective) with 99.95% confidence for image: image045.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# NG (Defective) with 97.70% confidence for image: image-30-C29029.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# NG (Defective) with 96.70% confidence for image: image028.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# NG (Defective) with 99.99% confidence for image: image-30-C29062.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# NG (Defective) with 92.71% confidence for image: image035.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# NG (Defective) with 99.99% confidence for image: image-30-C29053.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# NG (Defective) with 99.89% confidence for image: image036.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NG (Defective) with 99.99% confidence for image: image-30-C29058.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# NG (Defective) with 93.20% confidence for image: image-30-C29034.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# NG (Defective) with 99.98% confidence for image: image-30-C29047.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NG (Defective) with 93.61% confidence for image: image-30-C29039.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NG (Defective) with 99.92% confidence for image: image044.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# NG (Defective) with 99.98% confidence for image: image-30-C29045.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NG (Defective) with 99.99% confidence for image: image-30-C29040.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NG (Defective) with 99.98% confidence for image: image-30-C29052.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NG (Defective) with 99.64% confidence for image: image-30-C29027.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# NG (Defective) with 99.93% confidence for image: image034.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# NG (Defective) with 99.94% confidence for image: image048.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NG (Defective) with 99.99% confidence for image: image-30-C29059.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# NG (Defective) with 99.99% confidence for image: image-30-C29044.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# NG (Defective) with 99.99% confidence for image: image-30-C29033.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NG (Defective) with 99.97% confidence for image: image-30-C29026.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# GO (Correctly Aligned) with 45.79% confidence for image: image-30-C29031.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# NG (Defective) with 99.98% confidence for image: image-30-C29025.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# NG (Defective) with 99.98% confidence for image: image-30-C29024.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NG (Defective) with 99.98% confidence for image: image-30-C29054.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NG (Defective) with 99.00% confidence for image: image-30-C29007.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# NG (Defective) with 99.96% confidence for image: image-30-C29037.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# NG (Defective) with 99.03% confidence for image: image-30-C29008.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NG (Defective) with 100.00% confidence for image: image-30-C25053.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# NG (Defective) with 100.00% confidence for image: image-30-C25061.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NG (Defective) with 99.98% confidence for image: image-30-C29043.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NG (Defective) with 100.00% confidence for image: image-30-C25051.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# NG (Defective) with 95.01% confidence for image: image-30-C29009.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# NG (Defective) with 100.00% confidence for image: image-30-C25050.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# NG (Defective) with 100.00% confidence for image: image-30-C25054.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NG (Defective) with 100.00% confidence for image: image-30-C25049.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# NG (Defective) with 100.00% confidence for image: image-30-C25059.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# NG (Defective) with 100.00% confidence for image: image-30-C25055.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# NG (Defective) with 99.98% confidence for image: image-30-C29046.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# NG (Defective) with 100.00% confidence for image: image-30-C25045.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# NG (Defective) with 100.00% confidence for image: image-30-C25060.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# NG (Defective) with 100.00% confidence for image: image-30-C25052.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# NG (Defective) with 100.00% confidence for image: image-30-C25048.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# NG (Defective) with 99.88% confidence for image: image-30-C29038.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# NG (Defective) with 100.00% confidence for image: image-30-C25057.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# NG (Defective) with 100.00% confidence for image: image-30-C25040.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# NG (Defective) with 100.00% confidence for image: image-30-C25056.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# NG (Defective) with 99.73% confidence for image: image-30-C29028.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# NG (Defective) with 100.00% confidence for image: image-30-C25043.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# NG (Defective) with 99.97% confidence for image: image-30-C29036.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# NG (Defective) with 99.97% confidence for image: image-30-C29035.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# NG (Defective) with 100.00% confidence for image: image-30-C25037.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# NG (Defective) with 100.00% confidence for image: image-30-C25035.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# NG (Defective) with 99.97% confidence for image: image-30-C25041.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# NG (Defective) with 100.00% confidence for image: image-30-C25044.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# NG (Defective) with 100.00% confidence for image: image-30-C25062.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# NG (Defective) with 99.98% confidence for image: image-30-C25038.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# NG (Defective) with 99.24% confidence for image: image-30-C25034.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# NG (Defective) with 99.96% confidence for image: image-30-C25028.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# NG (Defective) with 100.00% confidence for image: image-30-C25058.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# NG (Defective) with 99.99% confidence for image: image-30-C25030.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# NG (Defective) with 99.51% confidence for image: image-30-C25031.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# NG (Defective) with 99.98% confidence for image: image-30-C25039.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# NG (Defective) with 99.99% confidence for image: image-30-C29023.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# NG (Defective) with 100.00% confidence for image: image-30-C25033.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# NG (Defective) with 99.97% confidence for image: image-30-C25042.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# NG (Defective) with 100.00% confidence for image: image-30-C25025.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# NG (Defective) with 99.08% confidence for image: image-30-C29001.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# NG (Defective) with 99.97% confidence for image: image-30-B24056.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# NG (Defective) with 100.00% confidence for image: image-30-C25047.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# NG (Defective) with 100.00% confidence for image: image-30-C25046.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# NG (Defective) with 99.99% confidence for image: image-30-B24063.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# NG (Defective) with 99.92% confidence for image: image-30-C25009.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# NG (Defective) with 100.00% confidence for image: image-30-C25024.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# NG (Defective) with 99.93% confidence for image: image-30-C25008.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# NG (Defective) with 99.97% confidence for image: image-30-B24052.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# NG (Defective) with 99.97% confidence for image: image-30-B24050.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# NG (Defective) with 99.99% confidence for image: image-30-B24059.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# NG (Defective) with 100.00% confidence for image: image-30-C25036.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# NG (Defective) with 99.99% confidence for image: image-30-C25029.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# NG (Defective) with 99.97% confidence for image: image-30-B24064.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# NG (Defective) with 99.97% confidence for image: image-30-B24049.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# NG (Defective) with 99.98% confidence for image: image-30-B24057.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# NG (Defective) with 99.97% confidence for image: image-30-B24062.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# NG (Defective) with 99.98% confidence for image: image-30-B24054.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# NG (Defective) with 99.98% confidence for image: image-30-B24053.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# NG (Defective) with 99.97% confidence for image: image-30-B24055.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# NG (Defective) with 100.00% confidence for image: image-30-C25023.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# NG (Defective) with 99.97% confidence for image: image-30-B24036.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# NG (Defective) with 99.97% confidence for image: image-30-B24044.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# NG (Defective) with 99.98% confidence for image: image-30-B24048.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# NG (Defective) with 87.29% confidence for image: image-30-B24035.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NG (Defective) with 99.79% confidence for image: image-30-B24042.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# NG (Defective) with 99.97% confidence for image: image-30-B24058.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# NG (Defective) with 99.20% confidence for image: image-30-B24040.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# NG (Defective) with 100.00% confidence for image: image-30-C25026.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# NG (Defective) with 99.22% confidence for image: image-30-B24043.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# NG (Defective) with 99.98% confidence for image: image-30-B24060.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# NG (Defective) with 99.97% confidence for image: image-30-B24061.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# NG (Defective) with 99.98% confidence for image: image-30-B24041.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# NG (Defective) with 99.76% confidence for image: image030.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NG (Defective) with 99.75% confidence for image: image-30-B24031.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# NG (Defective) with 99.98% confidence for image: image-30-B24024.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# NG (Defective) with 99.40% confidence for image: image-30-B24028.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# NG (Defective) with 100.00% confidence for image: image-30-C25063.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# NG (Defective) with 99.94% confidence for image: image-30-B24038.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# NG (Defective) with 98.38% confidence for image: image-30-B24007.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# NG (Defective) with 99.97% confidence for image: image-30-B24025.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# NG (Defective) with 99.98% confidence for image: image-30-B24026.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# NG (Defective) with 99.98% confidence for image: image-30-B24034.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# NG (Defective) with 99.96% confidence for image: image-30-C25027.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# NG (Defective) with 99.98% confidence for image: image-30-B24051.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# NG (Defective) with 99.99% confidence for image: image-30-B24045.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# NG (Defective) with 97.92% confidence for image: image-30-B24008.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# NG (Defective) with 99.81% confidence for image: image-30-B24030.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# NG (Defective) with 99.97% confidence for image: image-30-B24046.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# NG (Defective) with 99.98% confidence for image: image-30-B24047.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# NG (Defective) with 98.73% confidence for image: image-30-B24001.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# NG (Defective) with 98.80% confidence for image: image-30-B20058.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# NG (Defective) with 99.83% confidence for image: image-30-B24039.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# NG (Defective) with 94.58% confidence for image: image-30-B24032.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# NG (Defective) with 98.48% confidence for image: image-30-B20060.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# NG (Defective) with 98.81% confidence for image: image-30-B20053.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# NG (Defective) with 98.01% confidence for image: image-30-B20061.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# NG (Defective) with 98.40% confidence for image: image-30-B20052.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# NG (Defective) with 98.15% confidence for image: image-30-B20051.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# NG (Defective) with 99.57% confidence for image: image-30-B24029.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# NG (Defective) with 98.30% confidence for image: image-30-B20049.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# NG (Defective) with 98.05% confidence for image: image-30-B20041.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# NG (Defective) with 98.17% confidence for image: image-30-B20043.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# NG (Defective) with 98.28% confidence for image: image-30-B20057.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# NG (Defective) with 99.97% confidence for image: image-30-B24027.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# NG (Defective) with 99.62% confidence for image: image-30-B24009.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NG (Defective) with 99.98% confidence for image: image-30-B24037.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# NG (Defective) with 55.07% confidence for image: image-30-B20039.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NG (Defective) with 97.88% confidence for image: image-30-B20054.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# NG (Defective) with 98.80% confidence for image: image-30-B20056.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# NG (Defective) with 98.35% confidence for image: image-30-B20048.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# NG (Defective) with 98.72% confidence for image: image-30-B20047.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NG (Defective) with 98.26% confidence for image: image-30-B20063.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# NG (Defective) with 75.05% confidence for image: image-30-B20034.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# NG (Defective) with 98.07% confidence for image: image-30-B20035.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# NG (Defective) with 97.29% confidence for image: image-30-B20037.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# NG (Defective) with 75.74% confidence for image: image-30-B20030.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# NG (Defective) with 98.65% confidence for image: image-30-B20046.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# NG (Defective) with 98.78% confidence for image: image-30-B20050.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# NG (Defective) with 97.93% confidence for image: image-30-B20028.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# GO (Correctly Aligned) with 6.51% confidence for image: image-30-B20031.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NG (Defective) with 98.84% confidence for image: image-30-B20044.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# NG (Defective) with 98.33% confidence for image: image-30-B20045.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NG (Defective) with 97.17% confidence for image: image-30-B20027.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NG (Defective) with 98.19% confidence for image: image-30-B20055.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NG (Defective) with 98.23% confidence for image: image-30-B20024.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# NG (Defective) with 98.66% confidence for image: image-30-B20040.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# NG (Defective) with 98.64% confidence for image: image-30-B20025.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# NG (Defective) with 98.46% confidence for image: image-30-B20009.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NG (Defective) with 98.08% confidence for image: image-30-B20026.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NG (Defective) with 98.67% confidence for image: image-30-B20023.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# NG (Defective) with 98.78% confidence for image: image-30-B20033.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# NG (Defective) with 57.65% confidence for image: image-30-B20042.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# NG (Defective) with 98.34% confidence for image: image-30-B20036.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# NG (Defective) with 75.83% confidence for image: image-30-B20029.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# NG (Defective) with 98.27% confidence for image: image-30-B20038.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# NG (Defective) with 98.90% confidence for image: image-30-B20062.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# NG (Defective) with 76.38% confidence for image: image-30-B20008.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# NG (Defective) with 98.40% confidence for image: image-30-B20059.png
#
# Classifying images in directory: /content/drive/MyDrive/資料科學自學聖經/Fan_AOI_Austin/Photos/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# NG (Defective) with 76.62% confidence for image: imagee035.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GO (Correctly Aligned) with 6.50% confidence for image: image059.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# GO (Correctly Aligned) with 3.99% confidence for image: imagee041.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GO (Correctly Aligned) with 7.65% confidence for image: image062.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GO (Correctly Aligned) with 4.91% confidence for image: imagee044.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GO (Correctly Aligned) with 38.68% confidence for image: imagee039.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# GO (Correctly Aligned) with 3.84% confidence for image: imagee047.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GO (Correctly Aligned) with 7.95% confidence for image: image052.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# GO (Correctly Aligned) with 4.50% confidence for image: imagee045.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GO (Correctly Aligned) with 35.00% confidence for image: imagee042.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GO (Correctly Aligned) with 9.11% confidence for image: image025.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# GO (Correctly Aligned) with 4.65% confidence for image: image060.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# GO (Correctly Aligned) with 8.28% confidence for image: image058.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GO (Correctly Aligned) with 7.52% confidence for image: image054.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GO (Correctly Aligned) with 4.54% confidence for image: imagee038.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GO (Correctly Aligned) with 21.62% confidence for image: imagee043.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GO (Correctly Aligned) with 17.77% confidence for image: imagee040.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# GO (Correctly Aligned) with 4.31% confidence for image: image053.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GO (Correctly Aligned) with 4.90% confidence for image: image051.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GO (Correctly Aligned) with 8.50% confidence for image: image064.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# GO (Correctly Aligned) with 4.47% confidence for image: imagee046.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# GO (Correctly Aligned) with 6.77% confidence for image: image055.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GO (Correctly Aligned) with 49.01% confidence for image: image008.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# GO (Correctly Aligned) with 20.48% confidence for image: image009.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GO (Correctly Aligned) with 10.83% confidence for image: image056.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GO (Correctly Aligned) with 38.46% confidence for image: image043.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GO (Correctly Aligned) with 7.11% confidence for image: image049.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GO (Correctly Aligned) with 8.13% confidence for image: image044.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GO (Correctly Aligned) with 7.27% confidence for image: image046.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# GO (Correctly Aligned) with 7.19% confidence for image: image063.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# GO (Correctly Aligned) with 7.80% confidence for image: image037.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GO (Correctly Aligned) with 49.78% confidence for image: image029.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GO (Correctly Aligned) with 6.98% confidence for image: image027.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GO (Correctly Aligned) with 29.37% confidence for image: image030.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GO (Correctly Aligned) with 41.43% confidence for image: image001.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GO (Correctly Aligned) with 33.50% confidence for image: image040.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# GO (Correctly Aligned) with 5.34% confidence for image: imagee034.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GO (Correctly Aligned) with 8.42% confidence for image: image036.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# GO (Correctly Aligned) with 47.12% confidence for image: image007.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# GO (Correctly Aligned) with 31.96% confidence for image: image031.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# GO (Correctly Aligned) with 16.29% confidence for image: image038.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GO (Correctly Aligned) with 7.86% confidence for image: image034.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# NG (Defective) with 73.78% confidence for image: image035.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GO (Correctly Aligned) with 8.22% confidence for image: image050.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GO (Correctly Aligned) with 5.86% confidence for image: image057.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# GO (Correctly Aligned) with 4.36% confidence for image: image047.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GO (Correctly Aligned) with 39.37% confidence for image: image028.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# GO (Correctly Aligned) with 3.30% confidence for image: image-0-B22e060.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# GO (Correctly Aligned) with 3.30% confidence for image: imagee060.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# GO (Correctly Aligned) with 5.01% confidence for image: imagee058.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GO (Correctly Aligned) with 3.74% confidence for image: image-0-B22e062.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GO (Correctly Aligned) with 4.85% confidence for image: imagee056.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GO (Correctly Aligned) with 4.85% confidence for image: image-0-B22e056.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GO (Correctly Aligned) with 4.83% confidence for image: image026.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GO (Correctly Aligned) with 5.01% confidence for image: image-0-B22e058.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GO (Correctly Aligned) with 3.74% confidence for image: image-0-B22e064.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# GO (Correctly Aligned) with 4.30% confidence for image: imagee061.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# GO (Correctly Aligned) with 3.74% confidence for image: imagee064.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# GO (Correctly Aligned) with 4.30% confidence for image: image-0-B22e061.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GO (Correctly Aligned) with 4.65% confidence for image: imagee057.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GO (Correctly Aligned) with 3.45% confidence for image: imagee063.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GO (Correctly Aligned) with 35.00% confidence for image: image-0-B22e042.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GO (Correctly Aligned) with 4.98% confidence for image: imagee036.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GO (Correctly Aligned) with 5.21% confidence for image: imagee054.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GO (Correctly Aligned) with 5.21% confidence for image: image-0-B22e054.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# GO (Correctly Aligned) with 4.91% confidence for image: image-0-B22e044.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# GO (Correctly Aligned) with 4.50% confidence for image: image-0-B22e045.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GO (Correctly Aligned) with 4.47% confidence for image: image-0-B22e046.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GO (Correctly Aligned) with 3.74% confidence for image: image-0-B22e059.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GO (Correctly Aligned) with 3.84% confidence for image: image-0-B22e047.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# GO (Correctly Aligned) with 21.62% confidence for image: image-0-B22e043.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GO (Correctly Aligned) with 3.74% confidence for image: imagee062.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GO (Correctly Aligned) with 4.40% confidence for image: image-0-B22e051.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GO (Correctly Aligned) with 3.45% confidence for image: image-0-B22e063.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GO (Correctly Aligned) with 38.68% confidence for image: image-0-B22e039.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# GO (Correctly Aligned) with 4.40% confidence for image: imagee051.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# GO (Correctly Aligned) with 5.79% confidence for image: image024.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GO (Correctly Aligned) with 5.11% confidence for image: image045.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# GO (Correctly Aligned) with 6.18% confidence for image: image048.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# NG (Defective) with 76.62% confidence for image: image-0-B22e035.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GO (Correctly Aligned) with 17.77% confidence for image: image-0-B22e040.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GO (Correctly Aligned) with 3.99% confidence for image: image-0-B22e041.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# GO (Correctly Aligned) with 3.73% confidence for image: image-0-B22e055.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# GO (Correctly Aligned) with 21.92% confidence for image: image032.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# GO (Correctly Aligned) with 40.20% confidence for image: image039.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GO (Correctly Aligned) with 4.36% confidence for image: imagee050.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# GO (Correctly Aligned) with 4.36% confidence for image: image-0-B22e050.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# GO (Correctly Aligned) with 3.55% confidence for image: image-0-B22e053.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# GO (Correctly Aligned) with 3.92% confidence for image: imagee049.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# NG (Defective) with 53.25% confidence for image: imagee029.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# GO (Correctly Aligned) with 5.82% confidence for image: image041.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# GO (Correctly Aligned) with 3.92% confidence for image: image-0-B22e049.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# GO (Correctly Aligned) with 4.17% confidence for image: imagee048.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# GO (Correctly Aligned) with 3.74% confidence for image: imagee059.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# GO (Correctly Aligned) with 4.65% confidence for image: image-0-B22e057.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# GO (Correctly Aligned) with 4.20% confidence for image: imagee027.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# GO (Correctly Aligned) with 3.55% confidence for image: imagee053.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# GO (Correctly Aligned) with 4.20% confidence for image: image-0-B22e027.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# NG (Defective) with 96.02% confidence for image: image-0-B22e009.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# GO (Correctly Aligned) with 4.17% confidence for image: image-0-B22e048.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# NG (Defective) with 75.53% confidence for image: image-0-B22e007.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# GO (Correctly Aligned) with 3.73% confidence for image: imagee055.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# GO (Correctly Aligned) with 4.54% confidence for image: image-0-B22e038.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# GO (Correctly Aligned) with 3.88% confidence for image: imagee024.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# NG (Defective) with 53.25% confidence for image: image-0-B22e029.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# GO (Correctly Aligned) with 8.68% confidence for image: image061.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# GO (Correctly Aligned) with 4.29% confidence for image: imagee037.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# GO (Correctly Aligned) with 40.56% confidence for image: imagee028.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# NG (Defective) with 79.53% confidence for image: imagee001.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# GO (Correctly Aligned) with 5.34% confidence for image: image-0-B22e034.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# GO (Correctly Aligned) with 15.93% confidence for image: image-0-B22e032.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# GO (Correctly Aligned) with 4.98% confidence for image: image-0-B22e036.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# GO (Correctly Aligned) with 40.56% confidence for image: image-0-B22e028.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# GO (Correctly Aligned) with 4.15% confidence for image: image-0-B22e026.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# GO (Correctly Aligned) with 15.93% confidence for image: imagee032.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# GO (Correctly Aligned) with 28.66% confidence for image: image-0-B22e031.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# GO (Correctly Aligned) with 28.66% confidence for image: imagee031.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# GO (Correctly Aligned) with 4.15% confidence for image: imagee026.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# GO (Correctly Aligned) with 4.84% confidence for image: imagee025.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# GO (Correctly Aligned) with 39.59% confidence for image: image042.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GO (Correctly Aligned) with 3.88% confidence for image: image-0-B22e024.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GO (Correctly Aligned) with 4.29% confidence for image: image-0-B22e037.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GO (Correctly Aligned) with 24.51% confidence for image: imagee030.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GO (Correctly Aligned) with 24.51% confidence for image: image-0-B22e030.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# GO (Correctly Aligned) with 4.24% confidence for image: imagee052.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# GO (Correctly Aligned) with 4.24% confidence for image: image-0-B22e052.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# NG (Defective) with 76.69% confidence for image: image-0-B22e008.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GO (Correctly Aligned) with 4.84% confidence for image: image-0-B22e025.png

# %%
# !pip install gradio # Install the gradio library
# Out:
# Collecting gradio
#   Downloading gradio-5.8.0-py3-none-any.whl.metadata (16 kB)
# Collecting aiofiles<24.0,>=22.0 (from gradio)
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.7.1)
# Collecting fastapi<1.0,>=0.115.2 (from gradio)
#   Downloading fastapi-0.115.6-py3-none-any.whl.metadata (27 kB)
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.4.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting gradio-client==1.5.1 (from gradio)
#   Downloading gradio_client-1.5.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.28.0)
# Requirement already satisfied: huggingface-hub>=0.25.1 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.26.3)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.1.4)
# Collecting markupsafe~=2.0 (from gradio)
#   Downloading MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.10.12)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (11.0.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.10.3)
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.18 (from gradio)
#   Downloading python_multipart-0.0.19-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (6.0.2)
# Collecting ruff>=0.2.2 (from gradio)
#   Downloading ruff-0.8.2-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting safehttpx<0.2.0,>=0.1.6 (from gradio)
#   Downloading safehttpx-0.1.6-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio)
#   Downloading starlette-0.41.3-py3-none-any.whl.metadata (6.0 kB)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio)
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.15.0)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (4.12.2)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.32.1-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==1.5.1->gradio) (2024.10.0)
# Collecting websockets<15.0,>=10.0 (from gradio-client==1.5.1->gradio)
#   Downloading websockets-14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.25.1->gradio) (3.16.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.25.1->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.25.1->gradio) (4.66.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio) (2.27.1)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.25.1->gradio) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.25.1->gradio) (2.2.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Downloading gradio-5.8.0-py3-none-any.whl (57.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.2/57.2 MB 14.7 MB/s eta 0:00:00
# Downloading gradio_client-1.5.1-py3-none-any.whl (320 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.2/320.2 kB 21.7 MB/s eta 0:00:00
# Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading fastapi-0.115.6-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 7.0 MB/s eta 0:00:00
# Downloading MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Downloading python_multipart-0.0.19-py3-none-any.whl (24 kB)
# Downloading ruff-0.8.2-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 96.7 MB/s eta 0:00:00
# Downloading safehttpx-0.1.6-py3-none-any.whl (8.7 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-0.41.3-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 5.7 MB/s eta 0:00:00
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Downloading uvicorn-0.32.1-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 5.1 MB/s eta 0:00:00
# Downloading ffmpy-0.4.0-py3-none-any.whl (5.8 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading websockets-14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (168 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.2/168.2 kB 14.1 MB/s eta 0:00:00
# Installing collected packages: pydub, websockets, uvicorn, tomlkit, semantic-version, ruff, python-multipart, markupsafe, ffmpy, aiofiles, starlette, safehttpx, gradio-client, fastapi, gradio
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
# Successfully installed aiofiles-23.2.1 fastapi-0.115.6 ffmpy-0.4.0 gradio-5.8.0 gradio-client-1.5.1 markupsafe-2.1.5 pydub-0.25.1 python-multipart-0.0.19 ruff-0.8.2 safehttpx-0.1.6 semantic-version-2.10.0 starlette-0.41.3 tomlkit-0.13.2 uvicorn-0.32.1 websockets-14.1

# %% [markdown]
# # Step 3 - Upload the target image to be tested and classify GO or NG

# %%
import cv2
import numpy as np
import tensorflow as tf
import gradio as gr
from PIL import Image

# Load the pre-trained model
model = tf.keras.models.load_model("fan_model.h5")

# Recompile the model to suppress the warning
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Function to classify a single image
def classify_image(image):
    # Convert the image to a format suitable for OpenCV
    img = cv2.cvtColor(np.array(image), cv2.COLOR_RGB2BGR)
    img = cv2.resize(img, (80, 80))
    img = img.reshape(1, 80, 80, 3) / 255.0  # Normalize

    # Make prediction
    prediction = model.predict(img)

    # Classification logic
    if prediction is not None and len(prediction) > 0:
        # Set threshold for GO/NG classification
        # Adjusted based on expected results for the provided images
        class_idx = 1 if prediction[0] >= 0.5 else 0  # Threshold set to 0.6
        # confidence = prediction[0][0] * 100  # Confidence score in percentage

        if class_idx == 1:
            result_text = f"<div style='color: red; font-size: 24px; font-weight: bold;'>NG</div>"
            return result_text
        else:
            result_text = f"<div style='color: green; font-size: 24px; font-weight: bold;'>GO</div>"
            return result_text

    else:
        return "<div style='color: black; font-size: 20px;'>Unable to classify image</div>"

# Create Gradio interface
iface = gr.Interface(
    fn=classify_image,
    inputs=gr.Image(type="pil", label="Upload Image"),
    outputs=gr.HTML(label="Classification Result"),
    title="Cooling Fan GO/NG Inspection",
    description="Upload an image of a cooling fan to check if it is correctly aligned (GO) or defective (NG).",
)

# Launch the interface
iface.launch()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://6b9facf1877df7e12f.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://6b9facf1877df7e12f.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
